# %% [markdown]
# # Import numpy

# %%
import numpy as np

# %%
a = [1,3,5,7]

# %% [markdown]
# # Sumation

# %%
np.sum(a)
# Out:
# 16

# %% [markdown]
# # Products

# %%
np.prod(a)
# Out:
# 105

# %% [markdown]
# # Creating a function

# %%
def cube(x):
  result = x*x*x
  print(result)

# %% [markdown]
# # Calling function

# %%
cube(5)
# Out:
# 125
